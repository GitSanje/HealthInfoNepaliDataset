# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

url= "https://medlineplus.gov/languages/nepali.html"

html = urlopen(url).read().decode('utf-8')

soup = BeautifulSoup(html, 'html.parser')

sections = soup.find_all('section')

# %%
from GetInfo import GetHealthInfo

getinfo = GetHealthInfo(sections)

# %%
getinfo.getDict()
# Out:
# defaultdict(<function nested_defaultdict at 0x000001A75D1FC1F0>, {'A': defaultdict(<function nested_defaultdict at 0x000001A75D1FC1F0>, {'Acute Bronchitis': defaultdict(<function nested_defaultdict at 0x000001A75D1FC1F0>, {'Bronchitis -': 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/Bronchitis_Nepali.pdf'}), 'Advance Directives': defaultdict(<function nested_defaultdict at 0x000001A75D1FC1F0>, {'Advance Directives -': 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/AdvanceDirectives_NEPALI.pdf'}), 'Allergy': defaultdict(<function nested_defaultdict at 0x000001A75D1FC1F0>, {'Allergies -': 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/Allergies_Nepali.pdf'}), "Alzheimer's Disease": defaultdict(<function nested_defaultdict at 0x000001A75D1FC1F0>, {"Alzheimer's Disease -": 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/Alzheimers_NE.pdf'}), 'Anal Disorders': defaultdict(<function nested_defaultdict at 0x000001A75D1FC1F0>, {'Barium Enema -': 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/BariumEnema_Nepali.pdf'}), 'Anemia': defaultdict(<function nested_defaultdict at 0x000001A75D1FC1F0>, {'Anemia -': 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/Anemia_Nepali.pdf'}), 'Angina': defaultdict(<function nested_defaultdict at 0x000001A75D1FC1F0>, {'Nitroglycerin -': 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/Nitroglycerin_Nepali.pdf'}), 'Animal Bites': defaultdict(<function nested_defaultdict at 0x000001A75D1FC1F0>, {'Animal Bites and Scratches -': 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/AnimalBitesScratches_Nep.pdf'}), 'Ankle Injuries and Disorders': defaultdict(<function nested_defaultdict at 0x000001A75D1FC1F0>, {'Ankle Exercises -': 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/AnkleExercises_NEPALI.pdf', 'Ankle Sprain -': 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/AnkleSprain_NEPALI.pdf'}), 'Anthrax': defaultdict(<function nested_defaultdict at 0x000001A75D1FC1F0>, {'Anthrax: What You Need to Know -': 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/Anthrax_Nepali.pdf'}), 'Appendicitis': defaultdict(<function nested_defaultdict at 0x000001A75D1FC1F0>, {'Appendectomy -': 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/Appendectomy_NE.pdf', 'Simple Appendectomy for a Child -': 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/Appendectomy_child_Nep.pdf'}), 'Arm Injuries and Disorders': defaultdict(<function nested_defaultdict at 0x000001A75D1FC1F0>, {'Active Range of Motion Exercises: Wrists, Elbows, Forearms, and Shoulders -': 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/ActiveROM-WEFS_NEPALI.pdf', 'Wearing a Shoulder Sling -': 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/WearingShoulderSling_Nep.pdf'}), 'Arrhythmia': defaultdict(<function nested_defaultdict at 0x000001A75D1FC1F0>, {'Electrocardiogram (ECG or EKG) -': 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/Electrocardiogram_Nepali.pdf'}), 'Arthritis': defaultdict(<function nested_defaultdict at 0x000001A75D1FC1F0>, {'Arthritis -': 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/Arthritis_Nepali.pdf'}), 'Asthma': defaultdict(<function nested_defaultdict at 0x000001A75D1FC1F0>, {'Asthma -': 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/Asthma_NEP.pdf', 'Nebulizer Treatments -': 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/NebulizerTreatments_NEPALI.pdf', 'Peak Flow Meter -': 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/PeakFlowMeter_Nep.pdf'}), 'Asthma in Children': defaultdict(<function nested_defaultdict at 0x000001A75D1FC1F0>, {'Nebulizer Treatments -': 'https://storage.googleapis.com/healthinfotranslations-pdfdocs/NebulizerTreatments_NEPALI.pdf'}), 'Atrial Fibrillation': defaultdict(<function nested_defaultdict at 0x000001A75D1FC1F0>, {'At ...
# converted to csv, file : health_info_nepali.csv
# 'health_info_nepali.csv'

# %%
pd.read_csv('health_info_nepali.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pd.read_csv('health_info_nepali.csv')
#
# NameError: name 'pd' is not defined
